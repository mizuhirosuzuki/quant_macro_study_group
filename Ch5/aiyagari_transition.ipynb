# %%
import Pkg; Pkg.add("JLD")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed H5Zblosc ────────── v0.1.2
#    Installed MicrosoftMPI_jll ── v10.1.4+3
#    Installed Lz4_jll ─────────── v1.10.1+0
#    Installed MPICH_jll ───────── v4.3.2+0
#    Installed FileIO ──────────── v1.16.5
#    Installed MPIPreferences ──── v0.1.12
#    Installed HDF5_jll ────────── v1.14.6+0
#    Installed Hwloc_jll ───────── v2.13.0+1
#    Installed Blosc_jll ───────── v1.21.7+0
#    Installed libaec_jll ──────── v1.1.6+0
#    Installed OpenMPI_jll ─────── v5.0.10+0
#    Installed JLD ─────────────── v0.13.5
#    Installed XML2_jll ────────── v2.13.9+0
#    Installed Blosc ───────────── v0.7.3
#    Installed HDF5 ────────────── v0.17.2
#    Installed MPItrampoline_jll ─ v5.5.5+0
#   Installing 7 artifacts
#    Installed artifact Lz4                   320.0 KiB
#    Installed artifact Blosc                 31.1 KiB
#    Installed artifact libaec                41.5 KiB
#    Installed artifact XML2                  945.3 KiB
#    Installed artifact MPICH                 2.3 MiB
#    Installed artifact Hwloc                 2.6 MiB
#    Installed artifact HDF5                  4.9 MiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [4138dd39] + JLD v0.13.5
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [a74b3585] + Blosc v0.7.3
# ⌃ [5789e2e9] + FileIO v1.16.5
#   [c8ec2601] + H5Zblosc v0.1.2
#   [f67ccb44] + HDF5 v0.17.2
#   [4138dd39] + JLD v0.13.5
#   [3da0fdf6] + MPIPreferences v0.1.12
#   [0b7ba130] + Blosc_jll v1.21.7+0
# ⌅ [0234f1f7] + HDF5_jll v1.14.6+0
#   [e33a78d0] + Hwloc_jll v2.13.0+1
#   [5ced341a] + Lz4_jll v1.10.1+0
# ⌅ [7cb0a576] + MPICH_jll v4.3.2+0
#   [f1f71cc9] + MPItrampoline_jll v5.5.5+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+3
#   [fe0851c0] + OpenMPI_jll v5.0.10+0
# ⌅ [02c8fc9c] + XML2_jll v2.13.9+0
#   [477f73a3] + libaec_jll v1.1.6+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#     369.2 ms  ✓ MPIPreferences
#     344.8 ms  ✓ MicrosoftMPI_jll
#     382.8 ms  ✓ libaec_jll
#     382.0 ms  ✓ XML2_jll
#     385.4 ms  ✓ Lz4_jll
#     787.0 ms  ✓ MPItrampoline_jll
#     826.6 ms  ✓ Hwloc_jll
#     945.6 ms  ✓ Blosc_jll
#    1485.9 ms  ✓ FileIO
#     516.4 ms  ✓ OpenMPI_jll
#     578.4 ms  ✓ Blosc
#     939.2 ms  ✓ MPICH_jll
#    1479.9 ms  ✓ Plots → FileIOExt
#    1943.5 ms  ✓ HDF5_jll
#    4803.8 ms  ✓ HDF5
#     807.7 ms  ✓ H5Zblosc
#    1033.1 ms  ✓ JLD
#   17 dependencies successfully precompiled in 11 seconds. 423 already precompiled.

# %%
# load functrions made in advance
include("../quant_macro_book/chapter5/julia/tauchen.jl")

# import libraries
using Plots
using Optim
using Random
using Distributions 
using LaTeXStrings
using JLD # to save & load arrays like .mat in Matlab
